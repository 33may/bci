# %%
from data_loader import BCILoader, PreprocConfig
from torch_data import EEGEpochDataset

from typing import cast
import mne

mne.viz.set_browser_backend("qt")


# %matplotlib widget

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
config = PreprocConfig()

data_path = "../data/BCICIV_2a_gdf/raw"

loader = BCILoader(config, data_path)
# Out:
# 2025-08-31 00:27:42.011 | DEBUG    | data_loader:__init__:6 - === Files Loaded: =====
#  ['../data/BCICIV_2a_gdf/A01E.gdf', '../data/BCICIV_2a_gdf/A01T.gdf', '../data/BCICIV_2a_gdf/A02E.gdf', '../data/BCICIV_2a_gdf/A02T.gdf', '../data/BCICIV_2a_gdf/A03E.gdf', '../data/BCICIV_2a_gdf/A03T.gdf', '../data/BCICIV_2a_gdf/A04E.gdf', '../data/BCICIV_2a_gdf/A04T.gdf', '../data/BCICIV_2a_gdf/A05E.gdf', '../data/BCICIV_2a_gdf/A05T.gdf', '../data/BCICIV_2a_gdf/A06E.gdf', '../data/BCICIV_2a_gdf/A06T.gdf', '../data/BCICIV_2a_gdf/A07E.gdf', '../data/BCICIV_2a_gdf/A07T.gdf', '../data/BCICIV_2a_gdf/A08E.gdf', '../data/BCICIV_2a_gdf/A08T.gdf', '../data/BCICIV_2a_gdf/A09E.gdf', '../data/BCICIV_2a_gdf/A09T.gdf']
# 2025-08-31 00:27:42.012 | DEBUG    | data_loader:__init__:8 - === Train/Eval Separated =====
#  Train: 9 Eval: 9
# 2025-08-31 00:27:49.291 | DEBUG    | data_loader:__init__:16 - === Raw files Loaded: =====
#  [<RawGDF | A01E.gdf, 25 x 687000 (2748.0 s), ~131.1 MiB, data loaded>, <RawGDF | A01T.gdf, 25 x 672528 (2690.1 s), ~128.3 MiB, data loaded>, <RawGDF | A02E.gdf, 25 x 662666 (2650.7 s), ~126.4 MiB, data loaded>, <RawGDF | A02T.gdf, 25 x 677169 (2708.7 s), ~129.2 MiB, data loaded>, <RawGDF | A03E.gdf, 25 x 648775 (2595.1 s), ~123.8 MiB, data loaded>, <RawGDF | A03T.gdf, 25 x 660530 (2642.1 s), ~126.0 MiB, data loaded>, <RawGDF | A04E.gdf, 25 x 660047 (2640.2 s), ~125.9 MiB, data loaded>, <RawGDF | A04T.gdf, 25 x 600915 (2403.7 s), ~114.6 MiB, data loaded>, <RawGDF | A05E.gdf, 25 x 679863 (2719.5 s), ~129.7 MiB, data loaded>, <RawGDF | A05T.gdf, 25 x 686120 (2744.5 s), ~130.9 MiB, data loaded>, <RawGDF | A06E.gdf, 25 x 666373 (2665.5 s), ~127.1 MiB, data loaded>, <RawGDF | A06T.gdf, 25 x 678980 (2715.9 s), ~129.5 MiB, data loaded>, <RawGDF | A07E.gdf, 25 x 673135 (2692.5 s), ~128.4 MiB, data loaded>, <RawGDF | A07T.gdf, 25 x 681071 (2724.3 s), ~129.9 MiB, data loaded>, <RawGDF | A08E.gdf, 25 x 687792 (2751.2 s), ~131.2 MiB, data loaded>, <RawGDF | A08T.gdf, 25 x 675270 (2701.1 s), ~128.8 MiB, data loaded>, <RawGDF | A09E.gdf, 25 x 675098 (2700.4 s), ~128.8 MiB, data loaded>, <RawGDF | A09T.gdf, 25 x 673328 (2693.3 s), ~128.5 MiB, data loaded>]
# 2025-08-31 00:27:49.330 | DEBUG    | data_loader:__init__:18 - === Channesls renameds =====

# %%
loader.process_all();
# Out:
# 2025-08-31 00:43:28.359 | DEBUG    | data_loader:process_all:5 - All raw files processed

# %%
loader.save_epochs_pt("../data/BCICIV_2a_gdf/pt", tmin=-2.0, tmax=4.0)
# Out:
# 2025-08-31 01:07:34.474 | INFO     | data_loader:save_epochs_pt:20 - Saved epochs PT: ../data/BCICIV_2a_gdf/pt/A01E-eval-epo.pt
# 2025-08-31 01:07:34.724 | INFO     | data_loader:save_epochs_pt:20 - Saved epochs PT: ../data/BCICIV_2a_gdf/pt/A01T-train-epo.pt
# 2025-08-31 01:07:34.912 | INFO     | data_loader:save_epochs_pt:20 - Saved epochs PT: ../data/BCICIV_2a_gdf/pt/A02E-eval-epo.pt
# 2025-08-31 01:07:35.096 | INFO     | data_loader:save_epochs_pt:20 - Saved epochs PT: ../data/BCICIV_2a_gdf/pt/A02T-train-epo.pt
# 2025-08-31 01:07:35.262 | INFO     | data_loader:save_epochs_pt:20 - Saved epochs PT: ../data/BCICIV_2a_gdf/pt/A03E-eval-epo.pt
# 2025-08-31 01:07:35.409 | INFO     | data_loader:save_epochs_pt:20 - Saved epochs PT: ../data/BCICIV_2a_gdf/pt/A03T-train-epo.pt
# 2025-08-31 01:07:35.563 | INFO     | data_loader:save_epochs_pt:20 - Saved epochs PT: ../data/BCICIV_2a_gdf/pt/A04E-eval-epo.pt
# 2025-08-31 01:07:35.716 | INFO     | data_loader:save_epochs_pt:20 - Saved epochs PT: ../data/BCICIV_2a_gdf/pt/A04T-train-epo.pt
# 2025-08-31 01:07:35.867 | INFO     | data_loader:save_epochs_pt:20 - Saved epochs PT: ../data/BCICIV_2a_gdf/pt/A05E-eval-epo.pt
# 2025-08-31 01:07:36.021 | INFO     | data_loader:save_epochs_pt:20 - Saved epochs PT: ../data/BCICIV_2a_gdf/pt/A05T-train-epo.pt
# 2025-08-31 01:07:36.198 | INFO     | data_loader:save_epochs_pt:20 - Saved epochs PT: ../data/BCICIV_2a_gdf/pt/A06E-eval-epo.pt
# 2025-08-31 01:07:36.377 | INFO     | data_loader:save_epochs_pt:20 - Saved epochs PT: ../data/BCICIV_2a_gdf/pt/A06T-train-epo.pt
# 2025-08-31 01:07:36.555 | INFO     | data_loader:save_epochs_pt:20 - Saved epochs PT: ../data/BCICIV_2a_gdf/pt/A07E-eval-epo.pt
# 2025-08-31 01:07:36.715 | INFO     | data_loader:save_epochs_pt:20 - Saved epochs PT: ../data/BCICIV_2a_gdf/pt/A07T-train-epo.pt
# 2025-08-31 01:07:36.952 | INFO     | data_loader:save_epochs_pt:20 - Saved epochs PT: ../data/BCICIV_2a_gdf/pt/A08E-eval-epo.pt
# 2025-08-31 01:07:37.145 | INFO     | data_loader:save_epochs_pt:20 - Saved epochs PT: ../data/BCICIV_2a_gdf/pt/A08T-train-epo.pt
# 2025-08-31 01:07:37.336 | INFO     | data_loader:save_epochs_pt:20 - Saved epochs PT: ../data/BCICIV_2a_gdf/pt/A09E-eval-epo.pt
# 2025-08-31 01:07:37.557 | INFO     | data_loader:save_epochs_pt:20 - Saved epochs PT: ../data/BCICIV_2a_gdf/pt/A09T-train-epo.pt

# %%
from torch.utils.data import DataLoader

# %%
train_ds = EEGEpochDataset("../data/BCICIV_2a_gdf/pt", split="train")
eval_ds  = EEGEpochDataset("../data/BCICIV_2a_gdf/pt", split="eval")

train_dl = DataLoader(train_ds, batch_size=64, shuffle=True)
eval_dl  = DataLoader(eval_ds, batch_size=64, shuffle=False)

for X, y in train_dl:
    print(X.shape, y.shape)  # (B, C, T), (B,)
    break
# Out:
# ---------------------------------------------------------------------------
# UnpicklingError                           Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 train_ds = EEGEpochDataset("../data/BCICIV_2a_gdf/pt", split="train")
#       2 eval_ds  = EEGEpochDataset("../data/BCICIV_2a_gdf/pt", split="eval")
#       4 train_dl = DataLoader(train_ds, batch_size=64, shuffle=True)
#
# File ~/projects/bci/convformer/torch_data.py:9, in EEGEpochDataset.__init__(self, root, split)
#       7 self.files = []
#       8 for f in glob.glob(os.path.join(root, "*.pt")):
# ----> 9     d = torch.load(f, map_location="cpu")
#      10     if split == "all" or d["split"] == split:
#      11         self.files.append(f)
#
# File ~/miniconda3/envs/bci/lib/python3.11/site-packages/torch/serialization.py:1529, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1521                 return _load(
#    1522                     opened_zipfile,
#    1523                     map_location,
#    (...)   1526                     **pickle_load_args,
#    1527                 )
#    1528             except pickle.UnpicklingError as e:
# -> 1529                 raise pickle.UnpicklingError(_get_wo_message(str(e))) from None
#    1530         return _load(
#    1531             opened_zipfile,
#    1532             map_location,
#    (...)   1535             **pickle_load_args,
#    1536         )
#    1537 if mmap:
#
# UnpicklingError: Weights only load failed. This file can still be loaded, to do so you have two options, do those steps only if you trust the source of the checkpoint.
# 	(1) In PyTorch 2.6, we changed the default value of the `weights_only` argument in `torch.load` from `False` to `True`. Re-running `torch.load` with `weights_only` set to `False` will likely succeed, but it can result in arbitrary code execution. Do it only if you got the file from a trusted source.
# 	(2) Alternatively, to load with `weights_only=True` please check the recommended steps in the following error message.
# 	WeightsUnpickler error: Unsupported global: GLOBAL numpy._core.multiarray.scalar was not an allowed global by default. Please use `torch.serialization.add_safe_globals([numpy._core.multiarray.scalar])` or the `torch.serialization.safe_globals([numpy._core.multiarray.scalar])` context manager to allowlist this global if you trust this class/function.
#
# Check the documentation of torch.load to learn more about types accepted by default with weights_only https://pytorch.org/docs/stable/generated/torch.load.html.
